# %% [markdown]
# # 11장 데이터 다루기

# %% [markdown]
# [<img src="https://raw.githubusercontent.com/taehojo/taehojo.github.io/master/assets/images/linktocolab.png" align="left"/> ](https://colab.research.google.com/github/taehojo/deeplearning/blob/master/colab/ch11-colab.ipynb)

# %%
#실행에 필요한 pandas와 seaborn 라이브러리를 설치합니다. (이미 설치되어 있으면 이 과정은 생략합니다.)
# !pip install pandas
# !pip install seaborn

# %%
#필요한 라이브러리를 불러옵니다.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 피마 인디언 당뇨병 데이터셋을 불러옵니다. 
df = pd.read_csv('./data/pima-indians-diabetes3.csv')

# %%
# 처음 5줄을 봅니다.
df.head(5)
# Out:
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
# 정상과 당뇨 환자가 각각 몇 명씩인지 조사해 봅니다.
df["diabetes"].value_counts()
# Out:
# 0    500
# 1    268
# Name: diabetes, dtype: int64

# %%
# 각 정보별 특징을 좀 더 자세히 출력합니다.
df.describe()
# Out:
#          pregnant      plasma    pressure   thickness     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age    diabetes
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
# 각 항목이 어느정도의 상관 관계를 가지고 있는지 알아봅니다. 
df.corr()
# Out:
#            pregnant    plasma  pressure  thickness   insulin       bmi  \
# pregnant   1.000000  0.129459  0.141282  -0.081672 -0.073535  0.017683
# plasma     0.129459  1.000000  0.152590   0.057328  0.331357  0.221071
# pressure   0.141282  0.152590  1.000000   0.207371  0.088933  0.281805
# thickness -0.081672  0.057328  0.207371   1.000000  0.436783  0.392573
# insulin   -0.073535  0.331357  0.088933   0.436783  1.000000  0.197859
# bmi        0.017683  0.221071  0.281805   0.392573  0.197859  1.000000
# pedigree  -0.033523  0.137337  0.041265   0.183928  0.185071  0.140647
# age        0.544341  0.263514  0.239528  -0.113970 -0.042163  0.036242
# diabetes   0.221898  0.466581  0.065068   0.074752  0.130548  0.292695
#
#            pedigree       age  diabetes
# pregnant  -0.033523  0.544341  0.221898
# plasma     0.137337  0.263514  0.466581
# pressure   0.041265  0.239528  0.065068
# thickness  0.183928 -0.113970  0.074752
# insulin    0.185071 -0.042163  0.130548
# bmi        0.140647  0.036242  0.292695
# pedigree   1.000000  0.033561  0.173844
# age        0.033561  1.000000  0.238356
# diabetes   0.173844  0.238356  1.000000

# %%
# 데이터 간의 상관 관계를 그래프로 표현해 봅니다.
colormap = plt.cm.gist_heat   #그래프의 색상 구성을 정합니다.
plt.figure(figsize=(12,12))   #그래프의 크기를 정합니다.

# 그래프의 속성을 결정합니다. vmax의 값을 0.5로 지정해 0.5에 가까울수록 밝은색으로 표시되게 합니다.
sns.heatmap(df.corr(),linewidths=0.1,vmax=0.5, cmap=colormap, linecolor='white', annot=True)
plt.show()

# %% [markdown]
# ## 4. 중요한 데이터 추출하기

# %%
#plasma를 기준으로 각각 정상과 당뇨가 어느 정도 비율로 분포하는지 살펴봅니다. 
plt.hist(x=[df.plasma[df.diabetes==0], df.plasma[df.diabetes==1]], bins=30, histtype='barstacked', label=['normal','diabetes'])
plt.legend()

# %%
#BMI를 기준으로 각각 정상과 당뇨가 어느 정도 비율로 분포하는지 살펴봅니다. 
plt.hist(x=[df.bmi[df.diabetes==0], df.bmi[df.diabetes==1]], bins=30, histtype='barstacked', label=['normal','diabetes'])
plt.legend()

# %% [markdown]
# ## 5. 피마 인디언 당뇨병 예측 실행

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# pandas 라이브러리를 불러옵니다.
import pandas as pd

# 피마 인디언 당뇨병 데이터셋을 불러옵니다. 
df = pd.read_csv('./data/pima-indians-diabetes3.csv')

# %%
# 세부 정보를 X로 지정합니다.
X = df.iloc[:,0:8] # 데이터
# 당뇨병 여부를 Y로 지정합니다.
y = df.iloc[:,8] # 클래스 (라벨)

# %%
from tensorflow.keras.layers import Input
# 모델을 설정합니다.
model = Sequential()
model.add(Input(shape=(8,)))
model.add(Dense(12, input_dim=8, activation='relu', name='Dense_1'))
model.add(Dense(8, activation='relu', name='Dense_2'))
model.add(Dense(1, activation='sigmoid',name='Dense_3'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_1 (Dense)             (None, 12)                108
#
#  Dense_2 (Dense)             (None, 8)                 104
#
#  Dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델을 컴파일합니다.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델을 실행합니다.
history=model.fit(X, y, epochs=100, batch_size=5)
# Out:
# Epoch 1/100
# 154/154 [==============================] - 3s 6ms/step - loss: 2.6106 - accuracy: 0.5755
# Epoch 2/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.4420 - accuracy: 0.6211
# Epoch 3/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.2697 - accuracy: 0.6237
# Epoch 4/100
# 154/154 [==============================] - 1s 7ms/step - loss: 1.1111 - accuracy: 0.6224
# Epoch 5/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.9371 - accuracy: 0.6276
# Epoch 6/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.8901 - accuracy: 0.6185
# Epoch 7/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.7838 - accuracy: 0.6315
# Epoch 8/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.7994 - accuracy: 0.6562
# Epoch 9/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.7820 - accuracy: 0.6419
# Epoch 10/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.6961 - accuracy: 0.6602
# Epoch 11/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.8543 - accuracy: 0.6523
# Epoch 12/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.7163 - accuracy: 0.6810
# Epoch 13/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.7540 - accuracy: 0.6771
# Epoch 14/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6938 - accuracy: 0.6849
# Epoch 15/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6229 - accuracy: 0.6979
# Epoch 16/100
# 154/154 [==============================] - 1s 8ms/step - loss: 0.6470 - accuracy: 0.6901
# Epoch 17/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6702 - accuracy: 0.6654
# Epoch 18/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.6394 - accuracy: 0.6849
# Epoch 19/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6277 - accuracy: 0.7083
# Epoch 20/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6281 - accuracy: 0.6901
# Epoch 21/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5720 - accuracy: 0.7188
# Epoch 22/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6203 - accuracy: 0.7148
# Epoch 23/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5864 - accuracy: 0.7174
# Epoch 24/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6354 - accuracy: 0.7109
# Epoch 25/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.6618 - accuracy: 0.6836
# Epoch 26/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5898 - accuracy: 0.7018
# Epoch 27/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5786 - accuracy: 0.7161
# Epoch 28/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.6090 - accuracy: 0.6914
# Epoch 29/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6078 - accuracy: 0.7148
# Epoch 30/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5791 - accuracy: 0.7266
# Epoch 31/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.6174 - accuracy: 0.7240
# Epoch 32/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5927 - accuracy: 0.7135
# Epoch 33/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5722 - accuracy: 0.7188
# Epoch 34/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6010 - accuracy: 0.7161
# Epoch 35/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5888 - accuracy: 0.7188
# Epoch 36/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5741 - accuracy: 0.7279
# Epoch 37/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5455 - accuracy: 0.7344
# Epoch 38/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5640 - accuracy: 0.7357
# Epoch 39/100
# 154/154 [==============================] - 1s 8ms/step - loss: 0.8608 - accuracy: 0.6927
# Epoch 40/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5729 - accuracy: 0.7227
# Epoch 41/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5717 - accuracy: 0.7201
# Epoch 42/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5538 - accuracy: 0.7357
# Epoch 43/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5559 - accuracy: 0.7227
# Epoch 44/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5913 - accuracy: 0.7305
# Epoch 45/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5544 - accuracy: 0.7227
# Epoch 46/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5380 - accuracy: 0.7565
# Epoch 47/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5348 - accuracy: 0.7500
# Epoch 48/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5401 - accuracy: 0.7487
# Epoch 49/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5679 - accuracy: 0.7240
# Epoch 50/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.6011 - accuracy: 0.7305
# Epoch 51/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5378 - accuracy: 0.7526
# Epoch 52/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5471 - accuracy: 0.7409
# Epoch 53/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5274 - accuracy: 0.7448
# Epoch 54/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5256 - accuracy: 0.7604
# Epoch 55/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5499 - accuracy: 0.7357
# Epoch 56/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5847 - accuracy: 0.7487
# Epoch 57/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5985 - accuracy: 0.7122
# Epoch 58/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5789 - accuracy: 0.7461
# Epoch 59/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5391 - accuracy: 0.7253
# Epoch 60/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5628 - accuracy: 0.7331
# Epoch 61/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5804 - accuracy: 0.7096
# Epoch 62/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5364 - accuracy: 0.7448
# Epoch 63/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5788 - accuracy: 0.7396
# Epoch 64/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5409 - accuracy: 0.7188
# Epoch 65/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.6029 - accuracy: 0.7253
# Epoch 66/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5287 - accuracy: 0.7344
# Epoch 67/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5113 - accuracy: 0.7721
# Epoch 68/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5489 - accuracy: 0.7396
# Epoch 69/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5123 - accuracy: 0.7461
# Epoch 70/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5314 - accuracy: 0.7552
# Epoch 71/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5252 - accuracy: 0.7578
# Epoch 72/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5174 - accuracy: 0.7539
# Epoch 73/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5336 - accuracy: 0.7305
# Epoch 74/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5518 - accuracy: 0.7253
# Epoch 75/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5443 - accuracy: 0.7305
# Epoch 76/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5282 - accuracy: 0.7526
# Epoch 77/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5627 - accuracy: 0.7409
# Epoch 78/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5326 - accuracy: 0.7695
# Epoch 79/100
# 154/154 [==============================] - 1s 5ms/step - loss: 0.5298 - accuracy: 0.7643
# Epoch 80/100
# 154/154 [==============================] - 1s 5ms/step - loss: 0.5248 - accuracy: 0.7695
# Epoch 81/100
# 154/154 [==============================] - 1s 5ms/step - loss: 0.5160 - accuracy: 0.7617
# Epoch 82/100
# 154/154 [==============================] - 1s 4ms/step - loss: 0.5436 - accuracy: 0.7383
# Epoch 83/100
# 154/154 [==============================] - 1s 5ms/step - loss: 0.5158 - accuracy: 0.7578
# Epoch 84/100
# 154/154 [==============================] - 1s 5ms/step - loss: 0.5164 - accuracy: 0.7578
# Epoch 85/100
# 154/154 [==============================] - 1s 5ms/step - loss: 0.5118 - accuracy: 0.7552
# Epoch 86/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5463 - accuracy: 0.7409
# Epoch 87/100
# 154/154 [==============================] - 1s 5ms/step - loss: 0.5244 - accuracy: 0.7448
# Epoch 88/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5354 - accuracy: 0.7500
# Epoch 89/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5029 - accuracy: 0.7643
# Epoch 90/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4934 - accuracy: 0.7617
# Epoch 91/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4945 - accuracy: 0.7617
# Epoch 92/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.4977 - accuracy: 0.7487
# Epoch 93/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5089 - accuracy: 0.7513
# Epoch 94/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5124 - accuracy: 0.7656
# Epoch 95/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5379 - accuracy: 0.7565
# Epoch 96/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5152 - accuracy: 0.7643
# Epoch 97/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5659 - accuracy: 0.7331
# Epoch 98/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5068 - accuracy: 0.7539
# Epoch 99/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5123 - accuracy: 0.7513
# Epoch 100/100
# 154/154 [==============================] - 1s 6ms/step - loss: 0.5022 - accuracy: 0.7656

# %%
X.shape
# Out:
# (768, 8)
